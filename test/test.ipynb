# %%
import numpy as np
indices = np.linspace(0, 15, 11)
print(indices)
# Out:
# [ 0.   1.5  3.   4.5  6.   7.5  9.  10.5 12.  13.5 15. ]

# %%
for i, idx in enumerate(indices[1:], 1):
    print(f"Index {i}: {idx}")
# Out:
# Index 1: 1.5
# Index 2: 3.0
# Index 3: 4.5
# Index 4: 6.0
# Index 5: 7.5
# Index 6: 9.0
# Index 7: 10.5
# Index 8: 12.0
# Index 9: 13.5
# Index 10: 15.0
